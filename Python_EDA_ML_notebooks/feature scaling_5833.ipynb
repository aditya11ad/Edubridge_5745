# %% [markdown]
# ### Feature Scaling:

# %%
import pandas as pd

# %%
data=pd.DataFrame({'Values':[47,7,21,28,41,49,50,25,25,35,24]})
data
# Out:
#     Values
# 0       47
# 1        7
# 2       21
# 3       28
# 4       41
# 5       49
# 6       50
# 7       25
# 8       25
# 9       35
# 10      24

# %% [markdown]
# # Standardization (Z-score normalization)
# Rescaling of the features so that they have the properties of a standard normal distribution with μ=0 and σ=1,
# where μ is the mean (average) and σ is the standard deviation from the mean.
#
# About 68% of the values will lie be between -1 and 1.
#
# ![image.png](attachment:image.png)

# %%
from sklearn.preprocessing import StandardScaler
ss=StandardScaler()

# %%
data
# Out:
#     Values
# 0       47
# 1        7
# 2       21
# 3       28
# 4       41
# 5       49
# 6       50
# 7       25
# 8       25
# 9       35
# 10      24

# %%
data.mean()
# Out:
# Values    32.0
# dtype: float64

# %%
data_ss=ss.fit_transform(data)

# %%
data_ss
# Out:
# array([[ 1.15602469],
#        [-1.92670782],
#        [-0.84775144],
#        [-0.30827325],
#        [ 0.69361482],
#        [ 1.31016132],
#        [ 1.38722963],
#        [-0.53947819],
#        [-0.53947819],
#        [ 0.23120494],
#        [-0.6165465 ]])

# %%
data_ss.mean()
# Out:
# 0.0

# %% [markdown]
# ***

# %% [markdown]
# # Normalization(Min-Max scaling)
# The data is scaled to a fixed range usually 0 to 1.
# ![image.png](attachment:image.png)

# %%
(47-7)/(50-7)
# Out:
# 0.9302325581395349

# %%
from sklearn.preprocessing import MinMaxScaler
mm=MinMaxScaler()

# %%
data_mm= mm.fit_transform(data)

# %%
data_mm
# Out:
# array([[0.93023256],
#        [0.        ],
#        [0.3255814 ],
#        [0.48837209],
#        [0.79069767],
#        [0.97674419],
#        [1.        ],
#        [0.41860465],
#        [0.41860465],
#        [0.65116279],
#        [0.39534884]])

# %%
data['Standardized']=data_ss

data['Normalized']=data_mm

# %%
data
# Out:
#     Values  Standardized  Normalized
# 0       47      1.156025    0.930233
# 1        7     -1.926708    0.000000
# 2       21     -0.847751    0.325581
# 3       28     -0.308273    0.488372
# 4       41      0.693615    0.790698
# 5       49      1.310161    0.976744
# 6       50      1.387230    1.000000
# 7       25     -0.539478    0.418605
# 8       25     -0.539478    0.418605
# 9       35      0.231205    0.651163
# 10      24     -0.616547    0.395349

# %%
data['SNo']=data.index

# %%
data
# Out:
#     Values  Standardized  Normalized  SNo
# 0       47      1.156025    0.930233    0
# 1        7     -1.926708    0.000000    1
# 2       21     -0.847751    0.325581    2
# 3       28     -0.308273    0.488372    3
# 4       41      0.693615    0.790698    4
# 5       49      1.310161    0.976744    5
# 6       50      1.387230    1.000000    6
# 7       25     -0.539478    0.418605    7
# 8       25     -0.539478    0.418605    8
# 9       35      0.231205    0.651163    9
# 10      24     -0.616547    0.395349   10

# %%
import matplotlib.pyplot as plt

# %%
fig,axs=plt.subplots(1,3)
data.plot(kind='scatter',x='SNo', y='Values',color='r',ax=axs[0],figsize=(9,5))
data.plot(kind='scatter',x='SNo', y='Standardized',color='b',ax=axs[1])
data.plot(kind='scatter',x='SNo', y='Normalized',color='g',ax=axs[2])
fig.tight_layout()
